# %% [markdown]
# <a href="https://colab.research.google.com/github/nuwan-dharmarathna/Twitter-Sentiment-Analysis/blob/main/paper_shape_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !pip install ultralytics

# %%
import ultralytics

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 76.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="qZOo4n0fX61M2FzMIZMO")
project = rf.workspace("nuwandharmarathna").project("my-first-project-1jhwf")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to My-First-Project-5 in yolov8:: 100%|██████████| 2866/2866 [00:00<00:00, 7505.80it/s]

# %%
from ultralytics import YOLO

#load a model
model = YOLO("yolov8s.pt")

# Use the model
results = model.train(
    data="/content/paper_shape_dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    patience=30,
    device=0,
    workers=8,
    project="runs/train",
    name="paper_shapes_yolov8s",
    exist_ok=True
    ) #train the model
# Out:
# Ultralytics 8.4.8 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model = YOLO("/content/runs/detect/runs/train/paper_shapes_yolov8s/weights/best.pt")

# %%
model.predict(
    source="/content/paper_shape_dataset/test/images",
    conf=0.4,
    save=True
)
# Out:
# image 1/142 /content/paper_shape_dataset/test/images/circle_00045_jpg.rf.29bb752be87f14f7efb4cd198e36a22c.jpg: 640x640 1 circle, 17.6ms
# image 2/142 /content/paper_shape_dataset/test/images/circle_00061_jpg.rf.b05ceb0b0aadf5b5acaa0adc0d3bae05.jpg: 640x640 1 circle, 16.2ms
# image 3/142 /content/paper_shape_dataset/test/images/circle_00068_jpg.rf.4a36b4e3b8fa522af540fec42b128c38.jpg: 640x640 1 circle, 16.2ms
# image 4/142 /content/paper_shape_dataset/test/images/circle_00152_jpg.rf.fd65c8581aa53b7868ca6b074bc781ff.jpg: 640x640 1 circle, 16.2ms
# image 5/142 /content/paper_shape_dataset/test/images/circle_00155_jpg.rf.d4970c2aa4023bec4ff242c86ea10f63.jpg: 640x640 1 circle, 16.2ms
# image 6/142 /content/paper_shape_dataset/test/images/circle_00158_jpg.rf.ecbc738941dd5e4204812dd7c8d611c5.jpg: 640x640 1 circle, 16.2ms
# image 7/142 /content/paper_shape_dataset/test/images/circle_00166_jpg.rf.76c072c9f192413c010bb73ece58ec55.jpg: 640x640 1 circle, 13.7ms
# ...
